# %%
import pandas as pd

# %%
data = pd.read_csv("Data/vgchartz-2024.csv")

# %%
# show all columns
pd.set_option("display.max_columns", None)

# %%
data.sample(5)
# Out:
#                                                  img  \
# 20693                      /games/boxart/default.jpg
# 5191   /games/boxart/full_6760046AmericaFrontccc.jpg
# 39471  /games/boxart/full_7435624AmericaFrontccc.jpg
# 46277                   /games/boxart/9812730ccc.jpg
# 18856                      /games/boxart/default.jpg
#
#                                title console     genre  \
# 20693               Fun Ways to Sing     And    Action
# 5191        Goemon's Great Adventure     N64  Platform
# 39471         Walking with Dinosaurs     PS3      Misc
# 46277      Formula One: Built to Win     NES    Racing
# 18856  Rugby Union Team Manager 2015      PC    Action
#
#                                 publisher  \
# 20693                             Unknown
# 5191                               Konami
# 39471  Sony Computer Entertainment Europe
# 46277                    Seta Corporation
# 18856                Alternative Software
#
# ...
